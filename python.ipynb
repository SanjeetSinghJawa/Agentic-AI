# %% [markdown]
# <a href="https://colab.research.google.com/github/SanjeetSinghJawa/Agentic-AI/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Item1 = "Pizza"
Item2 = "Burger"
Item3 = "Fries"

Price_of_item1 = 300
Price_of_item2 = 300
Price_of_item3 = 300

Total_bill = Price_of_item1 + Price_of_item2 + Price_of_item3

print(Item1,"     :",Price_of_item1)
print(Item2,"    :",Price_of_item2)
print(Item3,"     :",Price_of_item3)
print("-----------------")
print("Total_bill :",Total_bill)

name = input("Enter your name")
print("name : ",name)
# Out:
# Pizza      : 300
# Burger     : 300
# Fries      : 300
# -----------------
# Total_bill : 900
# Enter your nameSanjeet
# name :  Sanjeet

# %%
name=input("enter your name : ")
print(name)
# Out:
# enter your name : hello
# hello
